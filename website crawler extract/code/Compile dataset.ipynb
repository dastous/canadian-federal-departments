# %%
import pandas as pd # to dataframes
import matplotlib.pyplot as plt #to define plot parameters
import seaborn as sns #to graphical plots
import numpy as np #to math

# %%
#AF= pd.read_excel('../SCMA/Dataset/AgriFood.xlsx')
#Services= pd.read_excel('../SCMA/Dataset/All services - Canada.ca.xlsx')
CA=pd.read_csv('../SCMA/Dataset/canada_ca_en.csv')
CSPS= pd.read_csv('../SCMA/Dataset/CSPS.csv')
ECCC= pd.read_csv('../SCMA/Dataset/environment_canada_gc_ca.csv')
HC= pd.read_csv('../SCMA/Dataset/HC.csv')
JC= pd.read_csv('../SCMA/Dataset/Justice.csv')
link_report= pd.read_csv('../SCMA/Dataset/link_report.csv')
link_report2= pd.read_csv('../SCMA/Dataset/link_report2.csv') #the same as link_report
NRCan= pd.read_csv('../SCMA/Dataset/natural_resources_canada.csv')
NEB= pd.read_csv('../SCMA/Dataset/NEB.csv')
NRC= pd.read_csv('../SCMA/Dataset/NRC.csv')
NRCan2= pd.read_csv('../SCMA/Dataset/NRCan.csv')
NSERC= pd.read_csv('../SCMA/Dataset/NSERC.csv')
OIC= pd.read_csv('../SCMA/Dataset/OIC.csv')
#OIC2= pd.read_csv('../SCMA/Dataset/OIC2.csv')
OPC= pd.read_csv('../SCMA/Dataset/OPC.csv')
PC= pd.read_csv('../SCMA/Dataset/park_canada.csv')
PSPC= pd.read_csv('../SCMA/Dataset/procurement_services_gc_ca.csv')
PSPC2= pd.read_csv('../SCMA/Dataset/PSPC.csv')
PS= pd.read_csv('../SCMA/Dataset/public_safety_gc_ca.csv')
#SCC= pd.read_excel('../SCMA/Dataset/SCC.xlsx')
StatsCan= pd.read_csv('../SCMA/Dataset/StatsCan.csv')
#TBS= pd.read_excel('../SCMA/Dataset/TBS.xlsx')
#testing= pd.read_excel('../SCMA/Dataset/test.xlsx')
WC= pd.read_csv('../SCMA/Dataset/weather_canada.csv')

# %%
list=[CA,CSPS,ECCC,HC,JC,link_report,NRCan,NEB,NRC,NRCan2,NSERC,OIC,OPC,PC,PSPC,PSPC2,PS,StatsCan,WC]
name=['CA','CSPS','ECCC','HC','JC','link_report','NRCan','NEB','NRC','NRCan2','NSERC','OIC','OPC','PC','PSPC','PSPC2','PS','StatsCan','WC']

# %%
d = globals()
df_list = [v for k, v in d.items() if isinstance(v, pd.DataFrame)]

# %%
#https://stackoverflow.com/questions/1663807/how-to-iterate-through-two-lists-in-parallel
for i,j in zip(list,name):
    print(j)
    print(i.nunique())
    print(i.groupby("Response")["Type"].count())
    print(i.groupby("Type")["URL"].count())
    print('\n')
# Out:
# CA
# URL         1949
# Response       2
# Type           1
# dtype: int64
# Response
# 200.0    1843
# 404.0      29
# Name: Type, dtype: int64
# Type
# Internal    1949
# Name: URL, dtype: int64
#
#
# CSPS
# URL         7027
# Response       7
# Type           2
# dtype: int64
# Response
# 200.0    2992
# 400.0       2
# 403.0      11
# 404.0    3727
# 500.0       5
# 503.0      78
# 999.0      14
# Name: Type, dtype: int64
# Type
# External    1604
# Internal    5423
# Name: URL, dtype: int64
#
#
# ECCC
# URL         201
# Response      2
# Type          2
# dtype: int64
# Response
# 200    200
# 999      1
# Name: Type, dtype: int64
# Type
# External     64
# Internal    137
# Name: URL, dtype: int64
#
#
# HC
# URL         8274
# Response      10
# Type           2
# dtype: int64
# Response
# 200.0    3008
# 403.0      25
# 404.0    5046
# 406.0       1
# 418.0       1
# 447.0       1
# 500.0       6
# 502.0       3
# 503.0      12
# 999.0       1
# Name: Type, dtype: int64
# ...
